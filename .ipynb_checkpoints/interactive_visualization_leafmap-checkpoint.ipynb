# %% [markdown]
# # Interactive Visualization of Raster and Vector Data
#
# **Author:** Masoud Hamad
# **Institution:** School of Computing Communication and Media Studies, Resilience Academy
# **Year:** 2025
#
# This notebook demonstrates interactive geospatial visualization using **leafmap** with the MapLibre GL backend. We'll explore various techniques for visualizing raster and vector data, including 3D visualizations, cloud-optimized formats, and more.
#
# **Data Source:** [Resilience Academy CRD](https://crd.resilienceacademy.ac.tz)

# %% [markdown]
# ## 1. Installation and Setup

# %%
# Install required packages
# %pip install -U leafmap localtileserver rioxarray mapclassify pmtiles
# Out:
# Collecting leafmap
#   Downloading leafmap-0.57.10-py2.py3-none-any.whl.metadata (17 kB)
# Collecting localtileserver
#   Downloading localtileserver-0.10.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: rioxarray in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (0.20.0)
# Collecting mapclassify
#   Using cached mapclassify-2.10.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting pmtiles
#   Using cached pmtiles-3.5.0-py3-none-any.whl.metadata (832 bytes)
# Collecting anywidget (from leafmap)
#   Downloading anywidget-0.9.21-py3-none-any.whl.metadata (8.9 kB)
# Collecting bqplot (from leafmap)
#   Using cached bqplot-0.12.45-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting duckdb>=1.4.1 (from leafmap)
#   Downloading duckdb-1.4.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.3 kB)
# Collecting folium (from leafmap)
#   Using cached folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting gdown (from leafmap)
#   Using cached gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting geojson (from leafmap)
#   Using cached geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: geopandas in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from leafmap) (1.1.1)
# Collecting ipyevents (from leafmap)
#   Using cached ipyevents-2.0.4-py3-none-any.whl.metadata (3.0 kB)
# Collecting ipyfilechooser (from leafmap)
#   Using cached ipyfilechooser-0.6.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting ipyleaflet (from leafmap)
#   Using cached ipyleaflet-0.20.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting ipyvuetify (from leafmap)
#   Using cached ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Collecting ipywidgets (from leafmap)
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting maplibre (from leafmap)
#   Downloading maplibre-0.3.6-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: matplotlib in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from leafmap) (3.10.7)
# Requirement already satisfied: numpy in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from leafmap) (2.3.5)
# Requirement already satisfied: pandas in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from leafmap) (2.3.3)
# Collecting plotly (from leafmap)
#   Downloading plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting pystac-client (from leafmap)
#   Using cached pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting python-box (from leafmap)
#   Downloading python_box-7.3.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (8.0 kB)
# Collecting scooby (from leafmap)
#   Downloading scooby-0.11.0-py3-none-any.whl.metadata (15 kB)
# Collecting whiteboxgui (from leafmap)
#   Using cached whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting xyzservices (from leafmap)
#   Downloading xyzservices-2025.11.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: click in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from localtileserver) (8.3.1)
# Collecting flask<4,>=2.0.0 (from localtileserver)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting Flask-Caching (from localtileserver)
#   Downloading Flask_Caching-2.3.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver)
#   Downloading flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting flask-restx>=1.3.0 (from localtileserver)
#   Downloading flask_restx-1.3.2-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver)
#   Downloading rio_tiler-8.0.4-py3-none-any.whl.metadata (11 kB)
# Collecting rio-cogeo (from localtileserver)
#   Downloading rio_cogeo-7.0.1-py3-none-any.whl.metadata (6.1 kB)
# Collecting requests (from localtileserver)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting server-thread (from localtileserver)
#   Downloading server_thread-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting werkzeug (from localtileserver)
#   Downloading werkzeug-3.1.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting blinker>=1.9.0 (from flask<4,>=2.0.0->localtileserver)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from flask<4,>=2.0.0->localtileserver)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.1.2 (from flask<4,>=2.0.0->localtileserver)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe>=2.1.1 (from flask<4,>=2.0.0->localtileserver)
#   Downloading markupsafe-3.0.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Requirement already satisfied: packaging in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from rioxarray) (25.0)
# Requirement already satisfied: rasterio>=1.4.3 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from rioxarray) (1.4.3)
# Requirement already satisfied: xarray>=2024.7.0 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from rioxarray) (2025.12.0)
# Requirement already satisfied: pyproj>=3.3 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from rioxarray) (3.7.2)
# Collecting networkx>=3.2 (from mapclassify)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: scikit-learn>=1.4 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from mapclassify) (1.7.2)
# Requirement already satisfied: scipy>=1.12 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from mapclassify) (1.16.3)
# Collecting aniso8601>=0.82 (from flask-restx>=1.3.0->localtileserver)
#   Downloading aniso8601-10.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Collecting jsonschema (from flask-restx>=1.3.0->localtileserver)
#   Using cached jsonschema-4.25.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting referencing (from flask-restx>=1.3.0->localtileserver)
#   Using cached referencing-0.37.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting importlib-resources (from flask-restx>=1.3.0->localtileserver)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from pandas->leafmap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from pandas->leafmap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from pandas->leafmap) (2025.2)
# Requirement already satisfied: certifi in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from pyproj>=3.3->rioxarray) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->leafmap) (1.17.0)
# Requirement already satisfied: affine in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from rasterio>=1.4.3->rioxarray) (2.4.0)
# Requirement already satisfied: attrs in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from rasterio>=1.4.3->rioxarray) (25.4.0)
# Requirement already satisfied: cligj>=0.5 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from rasterio>=1.4.3->rioxarray) (0.7.2)
# Requirement already satisfied: click-plugins in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from rasterio>=1.4.3->rioxarray) (1.1.1.2)
# Requirement already satisfied: pyparsing in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from rasterio>=1.4.3->rioxarray) (3.2.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from scikit-learn>=1.4->mapclassify) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from scikit-learn>=1.4->mapclassify) (3.6.0)
# Collecting psygnal>=0.8.1 (from anywidget->leafmap)
#   Downloading psygnal-0.15.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from anywidget->leafmap) (4.14.1)
# Requirement already satisfied: comm>=0.1.3 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from ipywidgets->leafmap) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from ipywidgets->leafmap) (9.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from ipywidgets->leafmap) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->leafmap)
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->leafmap)
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (2.19.2)
# Requirement already satisfied: stack_data in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->leafmap) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->leafmap) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->leafmap) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->leafmap) (0.7.0)
# Collecting traittypes>=0.0.6 (from bqplot->leafmap)
#   Using cached traittypes-0.2.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting cachelib>=0.9.0 (from Flask-Caching->localtileserver)
#   Downloading cachelib-0.13.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting branca>=0.6.0 (from folium->leafmap)
#   Downloading branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting beautifulsoup4 (from gdown->leafmap)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting filelock (from gdown->leafmap)
#   Downloading filelock-3.20.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: tqdm in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from gdown->leafmap) (4.67.1)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->gdown->leafmap)
#   Downloading soupsieve-2.8.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from geopandas->leafmap) (0.12.1)
# Requirement already satisfied: shapely>=2.0.0 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from geopandas->leafmap) (2.1.2)
# Collecting jupyter-leaflet<0.21,>=0.20 (from ipyleaflet->leafmap)
#   Using cached jupyter_leaflet-0.20.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting ipyvue<2,>=1.7 (from ipyvuetify->leafmap)
#   Using cached ipyvue-1.11.3-py2.py3-none-any.whl.metadata (987 bytes)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->flask-restx>=1.3.0->localtileserver)
#   Using cached jsonschema_specifications-2025.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->flask-restx>=1.3.0->localtileserver)
#   Downloading rpds_py-0.30.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting eval-type-backport (from maplibre->leafmap)
#   Downloading eval_type_backport-0.3.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting pydantic>=2.5.3 (from maplibre->leafmap)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.5.3->maplibre->leafmap)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.5.3->maplibre->leafmap)
#   Downloading pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.5.3->maplibre->leafmap)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from matplotlib->leafmap) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from matplotlib->leafmap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from matplotlib->leafmap) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from matplotlib->leafmap) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from matplotlib->leafmap) (12.0.0)
# Collecting narwhals>=1.15.1 (from plotly->leafmap)
#   Downloading narwhals-2.14.0-py3-none-any.whl.metadata (13 kB)
# Collecting pystac>=1.10.0 (from pystac[validation]>=1.10.0->pystac-client->leafmap)
#   Downloading pystac-1.14.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests->localtileserver)
#   Downloading charset_normalizer-3.4.4-cp312-cp312-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests->localtileserver)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->localtileserver)
#   Downloading urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown->leafmap)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting morecantile<8.0,>=5.0 (from rio-cogeo->localtileserver)
#   Downloading morecantile-7.0.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting cachetools (from rio-tiler->localtileserver)
#   Downloading cachetools-6.2.4-py3-none-any.whl.metadata (5.6 kB)
# Collecting color-operations (from rio-tiler->localtileserver)
#   Downloading color_operations-0.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Collecting httpx (from rio-tiler->localtileserver)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting numexpr (from rio-tiler->localtileserver)
#   Downloading numexpr-2.14.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting anyio (from httpx->rio-tiler->localtileserver)
#   Downloading anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting httpcore==1.* (from httpx->rio-tiler->localtileserver)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx->rio-tiler->localtileserver)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting uvicorn (from server-thread->localtileserver)
#   Using cached uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: executing>=1.2.0 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->leafmap) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->leafmap) (3.0.0)
# Requirement already satisfied: pure_eval in /Users/masoudhamad/miniconda3/envs/geoai/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->leafmap) (0.2.3)
# Collecting ipytree (from whiteboxgui->leafmap)
#   Using cached ipytree-0.2.2-py2.py3-none-any.whl.metadata (849 bytes)
# Collecting whitebox (from whiteboxgui->leafmap)
#   Using cached whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Downloading leafmap-0.57.10-py2.py3-none-any.whl (632 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.9/632.9 kB 949.4 kB/s eta 0:00:0031m? eta -:--:--
# Downloading localtileserver-0.10.7-py3-none-any.whl (33.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 3.3 MB/s eta 0:00:003.2 MB/s eta 0:00:01
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Using cached mapclassify-2.10.0-py3-none-any.whl (882 kB)
# Using cached pmtiles-3.5.0-py3-none-any.whl (16 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading duckdb-1.4.3-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 9.0 MB/s eta 0:00:00 MB/s eta 0:00:0101
# Downloading flask_restx-1.3.2-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 10.7 MB/s eta 0:00:0031m15.5 MB/s eta 0:00:01
# Downloading aniso8601-10.0.1-py2.py3-none-any.whl (52 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp312-cp312-macosx_11_0_arm64.whl (12 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.0 MB/s eta 0:00:00
# Downloading werkzeug-3.1.4-py3-none-any.whl (224 kB)
# Downloading anywidget-0.9.21-py3-none-any.whl (231 kB)
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Using cached widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Downloading psygnal-0.15.0-cp312-cp312-macosx_11_0_arm64.whl (576 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 576.0/576.0 kB 9.6 MB/s eta 0:00:00
# Using cached bqplot-0.12.45-py2.py3-none-any.whl (1.2 MB)
# Using cached traittypes-0.2.3-py2.py3-none-any.whl (8.1 kB)
# Downloading Flask_Caching-2.3.1-py3-none-any.whl (28 kB)
# Downloading cachelib-0.13.0-py3-none-any.whl (20 kB)
# Downloading flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Using cached folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading soupsieve-2.8.1-py3-none-any.whl (36 kB)
# Downloading filelock-3.20.1-py3-none-any.whl (16 kB)
# Using cached geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached ipyevents-2.0.4-py3-none-any.whl (102 kB)
# Using cached ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Using cached ipyleaflet-0.20.0-py3-none-any.whl (31 kB)
# Using cached jupyter_leaflet-0.20.0-py3-none-any.whl (1.1 MB)
# Downloading xyzservices-2025.11.0-py3-none-any.whl (93 kB)
# Using cached ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
# Using cached ipyvue-1.11.3-py2.py3-none-any.whl (2.7 MB)
# Using cached jsonschema-4.25.1-py3-none-any.whl (90 kB)
# Using cached jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Using cached referencing-0.37.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.30.0-cp312-cp312-macosx_11_0_arm64.whl (359 kB)
# Downloading maplibre-0.3.6-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 12.7 MB/s eta 0:00:00
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 12.2 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading eval_type_backport-0.3.1-py3-none-any.whl (6.1 kB)
# Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 11.5 MB/s eta 0:00:0031m11.6 MB/s eta 0:00:01
# Downloading narwhals-2.14.0-py3-none-any.whl (430 kB)
# Using cached pystac_client-0.9.0-py3-none-any.whl (41 kB)
# Downloading pystac-1.14.2-py3-none-any.whl (208 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp312-cp312-macosx_10_13_universal2.whl (208 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.2-py3-none-any.whl (131 kB)
# Downloading python_box-7.3.2-cp312-cp312-macosx_10_13_universal2.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.3 MB/s eta 0:00:00
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading rio_cogeo-7.0.1-py3-none-any.whl (21 kB)
# Downloading morecantile-7.0.0-py3-none-any.whl (50 kB)
# Downloading rio_tiler-8.0.4-py3-none-any.whl (277 kB)
# Downloading cachetools-6.2.4-py3-none-any.whl (11 kB)
# Downloading color_operations-0.2.0-cp312-cp312-macosx_11_0_arm64.whl (49 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
# Downloading numexpr-2.14.1-cp312-cp312-macosx_11_0_arm64.whl (152 kB)
# Downloading scooby-0.11.0-py3-none-any.whl (19 kB)
# Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Using cached uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Using cached whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
# Using cached ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
# Using cached whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
# Installing collected packages: pmtiles, aniso8601, xyzservices, widgetsnbextension, whitebox, urllib3, typing-inspection, traittypes, soupsieve, scooby, rpds-py, python-box, PySocks, pydantic-core, psygnal, numexpr, networkx, narwhals, markupsafe, jupyterlab_widgets, jupyter-leaflet, itsdangerous, importlib-resources, idna, h11, geojson, filelock, eval-type-backport, duckdb, color-operations, charset_normalizer, cachetools, cachelib, blinker, annotated-types, werkzeug, uvicorn, requests, referencing, pystac, pydantic, plotly, jinja2, httpcore, beautifulsoup4, anyio, server-thread, morecantile, mapclassify, jsonschema-specifications, ipywidgets, httpx, flask, branca, rio-tiler, rio-cogeo, maplibre, jsonschema, ipyvue, ipytree, ipyleaflet, ipyfilechooser, ipyevents, gdown, folium, flask-cors, Flask-Caching, bqplot, anywidget, whiteboxgui, ipyvuetify, flask-restx, pystac-client, localtileserver, leafmap
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75/75 [leafmap]5 [leafmap]32m73/75 [localtileserver]
# Successfully installed Flask-Caching-2.3.1 PySocks-1.7.1 aniso8601-10.0.1 annotated-types-0.7.0 anyio-4.12.0 anywidget-0.9.21 beautifulsoup4-4.14.3 blinker-1.9.0 bqplot-0.12.45 branca-0.8.2 cachelib-0.13.0 cachetools-6.2.4 charset_normalizer-3.4.4 color-operations-0.2.0 duckdb-1.4.3 eval-type-backport-0.3.1 filelock-3.20.1 flask-3.1.2 flask-cors-6.0.2 flask-restx-1.3.2 folium-0.20.0 gdown-5.2.0 geojson-3.2.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 importlib-resources-6.5.2 ipyevents-2.0.4 ipyfilechooser-0.6.0 ipyleaflet-0.20.0 ipytree-0.2.2 ipyvue-1.11.3 ipyvuetify-1.11.3 ipywidgets-8.1.8 itsdangerous-2.2.0 jinja2-3.1.6 jsonschema-4.25.1 jsonschema-specifications-2025.9.1 jupyter-leaflet-0.20.0 jupyterlab_widgets-3.0.16 leafmap-0.57.10 localtileserver-0.10.7 mapclassify-2.10.0 maplibre-0.3.6 markupsafe-3.0.3 morecantile-7.0.0 narwhals-2.14.0 networkx-3.6.1 numexpr-2.14.1 plotly-6.5.0 pmtiles-3.5.0 psygnal-0.15.0 pydantic-2.12.5 pydantic-core-2.41.5 pystac-1.14.2 pystac-client-0.9.0 python-box-7.3.2 referencing-0.37.0 requests-2.32.5 rio-cogeo-7.0.1 rio-tiler-8.0.4 rpds-py-0.30.0 scooby-0.11.0 server-thread-0.3.0 soupsieve-2.8.1 traittypes-0.2.3 typing-inspection-0.4.2 urllib3-2.6.2 uvicorn-0.38.0 werkzeug-3.1.4 whitebox-2.3.6 whiteboxgui-2.3.0 widgetsnbextension-4.0.15 xyzservices-2025.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import leafmap with MapLibre GL backend
import leafmap.maplibregl as leafmap
import numpy as np

# %% [markdown]
# ---
# ## 2. Basic Map Creation
#
# Let's start with creating simple interactive maps.

# %% [markdown]
# ---
# ## 2. Zanzibar Focus Examples
#
# Interactive maps centered on Zanzibar, Tanzania - showcasing local geospatial data visualization.

# %%
# Zanzibar - Basic Map View
m = leafmap.Map(
    center=[39.2083, -6.1659],  # Stone Town, Zanzibar
    zoom=10,
    style="positron"
)
m

# %%
# Zanzibar with Satellite Imagery
m = leafmap.Map(
    center=[39.2083, -6.1659],  # Stone Town, Zanzibar
    zoom=12,
    pitch=45,
    bearing=30
)
m.add_basemap("Esri.WorldImagery")
m.add_control("fullscreen", position="top-right")
m.add_control("navigation", position="top-right")
m

# %%
# Zanzibar - Unguja and Pemba Islands Overview
m = leafmap.Map(
    center=[39.5, -5.5],  # Between Unguja and Pemba
    zoom=8,
    style="liberty"
)
m.add_basemap("OpenTopoMap")

# Add markers for key locations
# Stone Town
m.add_marker(location=[-6.1659, 39.2083], popup="Stone Town - UNESCO World Heritage Site")
# Nungwi
m.add_marker(location=[-5.7264, 39.2983], popup="Nungwi Beach")
# Jozani Forest
m.add_marker(location=[-6.2667, 39.4167], popup="Jozani Chwaka Bay National Park")
# Pemba - Chake Chake
m.add_marker(location=[-5.2333, 39.7667], popup="Chake Chake, Pemba Island")

m

# %%
# Zanzibar - 3D Terrain View
m = leafmap.Map(
    center=[39.3, -6.1],  # Zanzibar
    zoom=11,
    pitch=60,
    bearing=-20,
    projection="globe"
)
m.add_basemap("Esri.WorldImagery")
m.set_terrain()
m

# %%
# Zanzibar - OpenStreetMap Buildings (Stone Town area)
m = leafmap.Map(
    center=[39.1880, -6.1622],  # Stone Town center
    zoom=16,
    pitch=60,
    bearing=45,
    style="positron"
)
m.add_basemap("OpenStreetMap.Mapnik")
m.add_overture_3d_buildings()
m

# %%
# Zanzibar - Drawing Control for Data Collection
# Useful for mapping flood zones, land use, etc.
m = leafmap.Map(
    center=[39.2083, -6.1659],
    zoom=13,
    style="positron"
)
m.add_basemap("Esri.WorldImagery")
m.add_draw_control(position="top-right")
m.add_control("geolocate", position="top-right")

# Instructions
print("Use the drawing tools to digitize features:")
print("- Polygon: Map flood-prone areas, land parcels")
print("- Line: Map roads, drainage channels")
print("- Point: Mark buildings, infrastructure")
m

# %%
# Zanzibar - Split Map Comparison (Before/After or Different Basemaps)
m = leafmap.Map(
    center=[39.2083, -6.1659],
    zoom=13,
    style="liberty"
)
m.split_map(
    left_layer="OpenStreetMap.Mapnik",
    right_layer="Esri.WorldImagery"
)
m

# %%
# Zanzibar - Building Footprints from Google/Microsoft Open Buildings
# This dataset includes building footprints for Africa including Zanzibar
url = "https://data.source.coop/vida/google-microsoft-open-buildings/pmtiles/go_ms_building_footprints.pmtiles"

m = leafmap.Map(
    center=[39.2083, -6.1659],  # Stone Town
    zoom=15
)
m.add_basemap("Esri.WorldImagery")

style = {
    "version": 8,
    "sources": {
        "example_source": {
            "type": "vector",
            "url": "pmtiles://" + url,
            "attribution": "Google/Microsoft Open Buildings",
        }
    },
    "layers": [
        {
            "id": "buildings",
            "source": "example_source",
            "source-layer": "building_footprints",
            "type": "fill",
            "paint": {
                "fill-color": "#ff6600",
                "fill-opacity": 0.6,
                "fill-outline-color": "#ffffff"
            },
        },
    ],
}

m.add_pmtiles(
    url,
    style=style,
    visible=True,
    opacity=1.0,
    tooltip=True,
)
m

# %%
# Zanzibar - Custom GeoJSON for local data
# Example: Creating sample flood risk zones
import json

# Sample flood risk zones in Stone Town area (example data)
flood_zones = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "properties": {"name": "Creek Road Area", "risk_level": "High", "risk_score": 3},
            "geometry": {
                "type": "Polygon",
                "coordinates": [[[39.185, -6.165], [39.190, -6.165], [39.190, -6.160], [39.185, -6.160], [39.185, -6.165]]]
            }
        },
        {
            "type": "Feature",
            "properties": {"name": "Malindi Area", "risk_level": "Medium", "risk_score": 2},
            "geometry": {
                "type": "Polygon",
                "coordinates": [[[39.190, -6.162], [39.195, -6.162], [39.195, -6.158], [39.190, -6.158], [39.190, -6.162]]]
            }
        },
        {
            "type": "Feature",
            "properties": {"name": "Forodhani Area", "risk_level": "Low", "risk_score": 1},
            "geometry": {
                "type": "Polygon",
                "coordinates": [[[39.188, -6.160], [39.192, -6.160], [39.192, -6.156], [39.188, -6.156], [39.188, -6.160]]]
            }
        }
    ]
}

m = leafmap.Map(
    center=[39.19, -6.16],
    zoom=15,
    style="positron"
)
m.add_basemap("OpenStreetMap.Mapnik")

# Add flood zones with color based on risk level
m.add_geojson(
    flood_zones,
    layer_type="fill",
    paint={
        "fill-color": [
            "match",
            ["get", "risk_level"],
            "High", "#ff0000",
            "Medium", "#ffaa00",
            "Low", "#00ff00",
            "#cccccc"
        ],
        "fill-opacity": 0.5
    },
    name="Flood Risk Zones"
)
m.add_popup("Flood Risk Zones")

# Add legend
legend_dict = {
    "High Risk": "ff0000",
    "Medium Risk": "ffaa00",
    "Low Risk": "00ff00"
}
m.add_legend(title="Flood Risk Level", legend_dict=legend_dict, position="bottom-right")
m

# %%
# Zanzibar - Loading data from Resilience Academy CRD
# You can load GeoJSON/Shapefiles from crd.resilienceacademy.ac.tz
# Example structure for loading local or remote data

m = leafmap.Map(
    center=[39.2083, -6.1659],
    zoom=12,
    style="positron"
)

# Example: Load data from Resilience Academy (replace with actual URL)
# crd_url = "https://crd.resilienceacademy.ac.tz/api/v2/datasets/your-dataset.geojson"
# m.add_geojson(crd_url, name="RA Data")

# For now, using OpenStreetMap as base
m.add_basemap("OpenStreetMap.Mapnik")

# Add HTML info panel
html = """
<div style="padding: 10px; background: white; border-radius: 8px; box-shadow: 0 2px 6px rgba(0,0,0,0.3);">
    <h4 style="margin: 0 0 8px 0; color: #00a6d6;">Resilience Academy</h4>
    <p style="margin: 0; font-size: 12px;">Data Source: crd.resilienceacademy.ac.tz</p>
    <p style="margin: 5px 0 0 0; font-size: 11px; color: gray;">Zanzibar Urban Resilience Data</p>
</div>
"""
m.add_html(html, position="top-left")
m

# %% [markdown]
# ---
# ## 3. Basic Map Creation
#
# Let's continue with more general interactive map examples.

# %%
# Simple interactive map
m = leafmap.Map()
m

# %%
# Customized map with center, zoom, pitch, bearing and globe projection
# Centered on Tanzania
m = leafmap.Map(
    center=[34.8888, -6.3690],  # [longitude, latitude] - Tanzania (Dodoma)
    zoom=5,
    pitch=0,
    bearing=0,
    projection="globe"
)
m

# %%
# Different basemap styles
m = leafmap.Map(style="positron")  # Light style good for data overlay
m

# %%
# Liberty style
m = leafmap.Map(style="liberty")
m

# %% [markdown]
# ---
# ## 3. Map Controls
#
# Add interactive controls to your maps.

# %%
# Geolocate control - find user's location
m = leafmap.Map()
m.add_control("geolocate", position="top-right")
m

# %%
# Fullscreen control
m = leafmap.Map(
    center=[11.255, 43.77],  # Florence, Italy
    zoom=13,
    style="positron",
    controls={}
)
m.add_control("fullscreen", position="top-right")
m

# %%
# Navigation control
m = leafmap.Map(
    center=[11.255, 43.77],
    zoom=13,
    style="positron",
    controls={}
)
m.add_control("navigation", position="top-right")
m

# %%
# Drawing control - allows users to draw on the map
m = leafmap.Map(center=[-100, 40], zoom=3, style="positron")
m.add_draw_control(position="top-right")
m

# %%
# Access drawn features (run after drawing something)
# m.draw_features_selected
# m.draw_feature_collection_all

# %% [markdown]
# ---
# ## 4. Adding Basemaps and Tile Layers

# %%
# Add different basemaps
m = leafmap.Map()
m.add_basemap("OpenTopoMap")
m

# %%
# Satellite imagery basemap
m = leafmap.Map()
m.add_basemap("Esri.WorldImagery")
m

# %%
# Interactive basemap selector
m = leafmap.Map()
m.add_basemap()  # Opens interactive selection
m

# %%
# Add custom XYZ tile layer (USGS Topographic)
m = leafmap.Map()
url = "https://basemap.nationalmap.gov/arcgis/rest/services/USGSTopo/MapServer/tile/{z}/{y}/{x}"
m.add_tile_layer(
    url,
    name="USGS Topo",
    attribution="USGS",
    opacity=1.0,
    visible=True
)
m

# %% [markdown]
# ---
# ## 5. WMS Layers
#
# Web Map Service (WMS) layers from external servers.

# %%
# New Jersey Natural Color Imagery
m = leafmap.Map(
    center=[-74.5447, 40.6892],  # New Jersey
    zoom=8,
    style="liberty"
)
url = "https://img.nj.gov/imagerywms/Natural2015"
layers = "Natural2015"
m.add_wms_layer(url, layers=layers, before_id="aeroway_fill")
m

# %%
# National Wetlands Inventory with legend
m = leafmap.Map(
    center=[-100.307965, 46.98692],  # North Dakota
    zoom=13,
    pitch=45,
    style="liberty"
)
m.add_basemap("Esri.WorldImagery")
url = "https://fwspublicservices.wim.usgs.gov/wetlandsmapservice/services/Wetlands/MapServer/WMSServer"
m.add_wms_layer(url, layers="1", name="NWI", opacity=0.6)
m.add_legend(builtin_legend="NWI", title="Wetland Type")
m

# %%
# NLCD Land Cover with legend
m = leafmap.Map(center=[-100, 40], zoom=3, style="positron")
m.add_basemap("Esri.WorldImagery")
url = "https://www.mrlc.gov/geoserver/mrlc_display/NLCD_2021_Land_Cover_L48/wms"
layers = "NLCD_2021_Land_Cover_L48"
m.add_wms_layer(url, layers=layers, name="NLCD 2021")
m.add_legend(
    title="NLCD Land Cover Type",
    builtin_legend="NLCD",
    bg_color="rgba(255, 255, 255, 0.5)",
    position="bottom-left",
)
m

# %% [markdown]
# ---
# ## 6. 3D Visualizations
#
# Create stunning 3D terrain and building visualizations.

# %%
# 3D Terrain - Mount St. Helens
m = leafmap.Map(
    center=[-122.1874314, 46.2022386],
    zoom=13,
    pitch=60,
    bearing=220,
    projection="globe",
)
m.add_basemap("Esri.WorldImagery")
m.set_terrain()
m

# %%
# 3D Buildings - New York City
m = leafmap.Map(
    center=[-74.01201, 40.70473],  # Lower Manhattan
    zoom=16,
    pitch=60,
    bearing=35,
)
m.add_basemap("Esri.WorldImagery", visible=False)
m.add_overture_3d_buildings()
m

# %%
# 3D Indoor mapping - Building floorplan
data = "https://maplibre.org/maplibre-gl-js/docs/assets/indoor-3d-map.geojson"

m = leafmap.Map(
    center=(-87.61694, 41.86625),  # Chicago
    zoom=17,
    pitch=40,
    bearing=20,
    style="positron"
)
m.add_basemap("OpenStreetMap.Mapnik")
m.add_geojson(
    data,
    layer_type="fill-extrusion",
    name="floorplan",
    paint={
        "fill-extrusion-color": ["get", "color"],
        "fill-extrusion-height": ["get", "height"],
        "fill-extrusion-base": ["get", "base_height"],
        "fill-extrusion-opacity": 0.5,
    },
)
m

# %% [markdown]
# ---
# ## 7. Vector Data Visualization
#
# Visualize points, lines, and polygons from various sources.

# %%
# Point data - World Cities
url = "https://github.com/opengeos/datasets/releases/download/world/world_cities.geojson"
m = leafmap.Map(style="liberty", projection="globe")
m.add_vector(url, name="cities")
m.add_popup("cities")
m

# %%
# Line data - Submarine Cables
url = "https://data.gishub.org/duckdb/cables.geojson"
m = leafmap.Map(style="liberty", projection="globe")
m.add_vector(url, name="cables")
m.add_popup("cables")
m

# %%
# Polygon data - Countries with population choropleth
m = leafmap.Map(style="liberty", projection="globe")
data = "https://github.com/opengeos/datasets/releases/download/vector/countries.geojson"
m.add_data(
    data,
    column="POP_EST",
    scheme="Quantiles",
    cmap="Blues",
    legend_title="Population",
    name="Population",
    before_id=m.first_symbol_layer_id,
)
m

# %%
# 3D Extruded countries by population
m = leafmap.Map(style="liberty", projection="globe")
data = "https://github.com/opengeos/datasets/releases/download/vector/countries.geojson"
m.add_data(
    data,
    column="POP_EST",
    scheme="Quantiles",
    cmap="Blues",
    legend_title="Population",
    name="Population",
    before_id=m.first_symbol_layer_id,
    extrude=True,  # 3D extrusion!
    scale_factor=1000,
)
m

# %% [markdown]
# ---
# ## 8. Raster Data Visualization
#
# Visualize satellite imagery and elevation data.

# %%
# Download and visualize Landsat imagery
url = "https://github.com/opengeos/datasets/releases/download/raster/landsat.tif"
filepath = "landsat.tif"
leafmap.download_file(url, filepath, quiet=True)

m = leafmap.Map()
# True color composite (RGB)
m.add_raster(filepath, indexes=[3, 2, 1], vmin=0, vmax=100, name="Landsat-321")
# False color composite (NIR-R-G)
m.add_raster(filepath, indexes=[4, 3, 2], vmin=0, vmax=100, name="Landsat-432")
m

# %%
# Digital Elevation Model (DEM)
url = "https://github.com/opengeos/datasets/releases/download/raster/srtm90.tif"
filepath = "srtm90.tif"
leafmap.download_file(url, filepath, quiet=True)

m = leafmap.Map(style="liberty")
m.add_raster(filepath, colormap="terrain", name="DEM")
m

# %% [markdown]
# ---
# ## 9. Cloud Optimized GeoTIFF (COG)
#
# Stream large rasters directly from the cloud without downloading.

# %%
# Libya flood before/after comparison
m = leafmap.Map(style="liberty")
before = "https://github.com/opengeos/datasets/releases/download/raster/Libya-2023-07-01.tif"
after = "https://github.com/opengeos/datasets/releases/download/raster/Libya-2023-09-13.tif"
m.add_cog_layer(before, name="Before", attribution="Maxar")
m.add_cog_layer(after, name="After", attribution="Maxar", fit_bounds=True)
m

# %%
# DEM with colorbar
m = leafmap.Map(style="liberty")
dem = "https://github.com/opengeos/datasets/releases/download/raster/dem.tif"
m.add_cog_layer(
    dem,
    name="DEM",
    colormap_name="terrain",
    rescale="0, 1500",
    fit_bounds=True,
    nodata=np.nan,
)
m.add_colorbar(
    cmap="terrain",
    vmin=0,
    vmax=1500,
    label="Elevation (m)",
    position="bottom-right"
)
m

# %%
# Vertical transparent colorbar
m = leafmap.Map(style="liberty")
dem = "https://github.com/opengeos/datasets/releases/download/raster/dem.tif"
m.add_cog_layer(
    dem,
    name="DEM",
    colormap_name="terrain",
    rescale="0, 1500",
    nodata=np.nan,
    fit_bounds=True,
)
m.add_colorbar(
    cmap="terrain",
    vmin=0,
    vmax=1500,
    label="Elevation (m)",
    position="bottom-right",
    width=0.2,
    height=3,
    orientation="vertical",
    transparent=True,
)
m

# %% [markdown]
# ---
# ## 10. STAC (SpatioTemporal Asset Catalog)
#
# Access satellite imagery through standardized STAC catalogs.

# %%
# SPOT-5 satellite imagery from Canada
m = leafmap.Map()
url = "https://canada-spot-ortho.s3.amazonaws.com/canada_spot_orthoimages/canada_spot5_orthoimages/S5_2007/S5_11055_6057_20070622/S5_11055_6057_20070622.json"

# Panchromatic band
m.add_stac_layer(url, bands=["pan"], name="Panchromatic", vmin=0, vmax=150)

# RGB composite
m.add_stac_layer(url, bands=["B4", "B3", "B2"], name="RGB", vmin=0, vmax=150)
m

# %% [markdown]
# ---
# ## 11. PMTiles Visualization
#
# Efficient cloud-native vector tile format.

# %%
# Google/Microsoft Building Footprints
url = "https://data.source.coop/vida/google-microsoft-open-buildings/pmtiles/go_ms_building_footprints.pmtiles"
metadata = leafmap.pmtiles_metadata(url)
print(f"Layer names: {metadata['layer_names']}")
print(f"Bounds: {metadata['bounds']}")

# %%
m = leafmap.Map(center=[0, 20], zoom=2)
m.add_basemap("Esri.WorldImagery", visible=False)

style = {
    "version": 8,
    "sources": {
        "example_source": {
            "type": "vector",
            "url": "pmtiles://" + url,
            "attribution": "PMTiles",
        }
    },
    "layers": [
        {
            "id": "buildings",
            "source": "example_source",
            "source-layer": "building_footprints",
            "type": "fill",
            "paint": {"fill-color": "#3388ff", "fill-opacity": 0.5},
        },
    ],
}

m.add_pmtiles(
    url,
    style=style,
    visible=True,
    opacity=1.0,
    tooltip=True,
)
m

# %%
# Fields of the World - Agricultural field boundaries
url = "https://data.source.coop/kerner-lab/fields-of-the-world/ftw-sources.pmtiles"

m = leafmap.Map()
style = {
    "layers": [
        {
            "id": "Field Polygon",
            "source": "example_source",
            "source-layer": "ftw-sources",
            "type": "fill",
            "paint": {
                "fill-color": "#ffff00",
                "fill-opacity": 0.2,
            },
        },
        {
            "id": "Field Outline",
            "source": "example_source",
            "source-layer": "ftw-sources",
            "type": "line",
            "paint": {"line-color": "#ff0000", "line-width": 1, "line-opacity": 1},
        },
    ],
}

m.add_basemap("Satellite")
m.add_pmtiles(url, style=style, name="FTW", zoom_to_layer=False)
m

# %%
# 3D Overture Buildings - NYC
url = "https://data.source.coop/cholmes/overture/overture-buildings.pmtiles"

m = leafmap.Map(
    center=[-74.0095, 40.7046],  # NYC Financial District
    zoom=16,
    pitch=60,
    bearing=-17,
    style="positron"
)
m.add_basemap("OpenStreetMap.Mapnik")
m.add_basemap("Esri.WorldImagery", visible=False)

style = {
    "layers": [
        {
            "id": "buildings",
            "source": "example_source",
            "source-layer": "buildings",
            "type": "fill-extrusion",
            "filter": [">", ["get", "height"], 0],
            "paint": {
                "fill-extrusion-color": [
                    "interpolate",
                    ["linear"],
                    ["get", "height"],
                    0, "lightgray",
                    200, "royalblue",
                    400, "lightblue",
                ],
                "fill-extrusion-height": ["*", ["get", "height"], 1],
            },
        },
    ],
}

m.add_pmtiles(
    url,
    style=style,
    visible=True,
    opacity=1.0,
    tooltip=True,
    template="Height: {{height}}<br>Country: {{country_iso}}",
    fit_bounds=False,
)
m

# %% [markdown]
# ---
# ## 12. H3 Hexagonal Grid
#
# Uber's H3 hierarchical spatial index for aggregating data.

# %%
# Load H3 hexagon data
url = "https://data.gishub.org/duckdb/h3_res4_geo.parquet"
gdf = leafmap.read_vector(url)
gdf.head()

# %%
# 2D Hexagon visualization
m = leafmap.Map()
m.add_basemap("Esri.WorldImagery", before_id=m.first_symbol_layer_id, visible=False)
m.add_data(
    gdf,
    column="building_count",
    scheme="JenksCaspall",
    cmap="inferno",
    outline_color="rgba(255, 255, 255, 0)",
    name="H3 Hexagon",
    before_id=m.first_symbol_layer_id,
)
m

# %%
# 3D Extruded hexagons
m = leafmap.Map(
    center=[7.062832, -4.144790],
    pitch=45.5,
    zoom=1.57
)
m.add_basemap("Esri.WorldImagery", before_id=m.first_symbol_layer_id, visible=False)
m.add_data(
    gdf,
    column="building_count",
    scheme="JenksCaspall",
    cmap="inferno",
    outline_color="rgba(255, 255, 255, 0)",
    name="H3 Hexagon",
    before_id=m.first_symbol_layer_id,
    extrude=True,  # 3D extrusion
    fit_bounds=False,
)
m

# %% [markdown]
# ---
# ## 13. Video Overlay

# %%
# Drone video overlay on map
m = leafmap.Map(
    center=[-122.514426, 37.562984],
    zoom=17,
    bearing=-96,
    style="liberty"
)
m.add_basemap("Esri.WorldImagery")

urls = [
    "https://static-assets.mapbox.com/mapbox-gl-js/drone.mp4",
    "https://static-assets.mapbox.com/mapbox-gl-js/drone.webm",
]
coordinates = [
    [-122.51596391201019, 37.56238816766053],
    [-122.51467645168304, 37.56410183312965],
    [-122.51309394836426, 37.563391708549425],
    [-122.51423120498657, 37.56161849366671],
]
m.add_video(urls, coordinates)
m

# %% [markdown]
# ---
# ## 14. Custom HTML Content

# %%
# Add custom HTML to map
m = leafmap.Map(center=[-100, 40], zoom=3, style="positron")

html = """
<html>
<style>
body {
  font-size: 20px;
  font-family: Arial, sans-serif;
}
</style>
<body>
<span style='font-size:80px;'>&#127758;</span>
<h3>Resilience Academy</h3>
<p>Interactive Geospatial Visualization</p>
</body>
</html>
"""
m.add_html(html, bg_color="transparent")
m

# %% [markdown]
# ---
# ## 15. Custom Legend

# %%
# Custom legend with specific colors
m = leafmap.Map(center=[-100, 40], zoom=3, style="positron")
m.add_basemap("Esri.WorldImagery")
url = "https://www.mrlc.gov/geoserver/mrlc_display/NLCD_2021_Land_Cover_L48/wms"
layers = "NLCD_2021_Land_Cover_L48"
m.add_wms_layer(url, layers=layers, name="NLCD 2021")

legend_dict = {
    "11 Open Water": "466b9f",
    "12 Perennial Ice/Snow": "d1def8",
    "21 Developed, Open Space": "dec5c5",
    "22 Developed, Low Intensity": "d99282",
    "23 Developed, Medium Intensity": "eb0000",
    "24 Developed, High Intensity": "ab0000",
    "31 Barren Land": "b3ac9f",
    "41 Deciduous Forest": "68ab5f",
    "42 Evergreen Forest": "1c5f2c",
    "43 Mixed Forest": "b5c58f",
    "52 Shrub/Scrub": "ccb879",
    "71 Grassland/Herbaceous": "dfdfc2",
    "81 Pasture/Hay": "dcd939",
    "82 Cultivated Crops": "ab6c28",
    "90 Woody Wetlands": "b8d9eb",
    "95 Emergent Herbaceous Wetlands": "6c9fb8",
}

m.add_legend(
    title="NLCD Land Cover Type",
    legend_dict=legend_dict,
    bg_color="rgba(255, 255, 255, 0.5)",
    position="bottom-left",
)
m

# %% [markdown]
# ---
# ## Summary
#
# This notebook demonstrated various interactive visualization techniques using leafmap:
#
# 1. **Zanzibar Examples**: Local maps, building footprints, flood risk zones
# 2. **Basic Maps**: Creating maps with different styles, projections, and controls
# 3. **Basemaps**: Adding tile layers, WMS services
# 4. **3D Visualization**: Terrain, buildings, indoor maps
# 5. **Vector Data**: Points, lines, polygons with styling and popups
# 6. **Raster Data**: Local files, COG, STAC
# 7. **PMTiles**: Cloud-native vector tiles
# 8. **H3 Hexagons**: Spatial aggregation and visualization
# 9. **Multimedia**: Video overlays, custom HTML
# 10. **Legends & Colorbars**: Built-in and custom legends
#
# ### Key Takeaways
#
# - Use **cloud-native formats** (COG, PMTiles) for better performance
# - Choose **appropriate color schemes** for your data type
# - **3D visualization** can reveal patterns not visible in 2D
# - **Interactive controls** improve user engagement
#
# ### Resources
#
# - [Resilience Academy CRD](https://crd.resilienceacademy.ac.tz)
# - [leafmap documentation](https://leafmap.org)
# - [MapLibre GL JS](https://maplibre.org)
